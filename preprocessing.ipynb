# %%
import pandas as pd
import os

# %%
tables = []
for n, file in enumerate(os.listdir('./')):
    if 'xls' in file:
        tables.append(pd.read_excel(file))

# %%
output = pd.concat(tables)

# %%
output.head()
# Out:
#    ATP  Location                              Tournament       Date  \
# 0    1  Adelaide  Next Generation Adelaide International 2006-01-02
# 1    1  Adelaide  Next Generation Adelaide International 2006-01-02
# 2    1  Adelaide  Next Generation Adelaide International 2006-01-02
# 3    1  Adelaide  Next Generation Adelaide International 2006-01-02
# 4    1  Adelaide  Next Generation Adelaide International 2006-01-02
#
#           Series    Court Surface      Round  Best of            Winner  ...  \
# 0  International  Outdoor    Hard  1st Round        3        Berdych T.  ...
# 1  International  Outdoor    Hard  1st Round        3  Kohlschreiber P.  ...
# 2  International  Outdoor    Hard  1st Round        3        Malisse X.  ...
# 3  International  Outdoor    Hard  1st Round        3        Robredo T.  ...
# 4  International  Outdoor    Hard  1st Round        3          Ancic M.  ...
#
#   AvgW AvgL IWW  IWL  GBW  GBL  SBW SBL B&WW B&WL
# ...

# %%
output.to
# Out:
# (55460, 54)
